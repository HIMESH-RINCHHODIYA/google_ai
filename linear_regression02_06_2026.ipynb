# %% [markdown]
# <a href="https://colab.research.google.com/github/HIMESH-RINCHHODIYA/google_ai/blob/main/linear_regression02_06_2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.datasets import load_iris
X,y = load_iris(return_X_y=True)
model = LogisticRegression(max_iter=800).fit(X,y)
print(model.predict(X[:5]))
# Out:
# [0 0 0 0 0]

# %%
import pandas as pd
data = {
    'Name':['Alice','Bob','Charlie','David','Alice'],
    'Age':[25,None,30,35,None],
    'City':['New York','Los Angeles',None,'Chicago','New York']
}
df = pd.DataFrame(data)

print("Original Dataframe with missing values:")
print(df)

print("\nMissing values in each column:")
print(df.isnull().sum())

# Fill missing values
df_filled = df.fillna({'Age': df['Age'].mean(), 'City': 'Unknown'})
print("\nDataframe after filling missing values:")
print(df_filled)

# Remove rows with missing values (demonstrate dropna)
df_cleaned = df.dropna()
print("\nDataframe after dropping missing values:")
print(df_cleaned)


#4..remove duplicate
df_no_duplicates = df.drop_duplicates()
print("\nDataframe after removing duplicates:")
print(df_no_duplicates)

#5..convert Data Types
# Fill NaN values in 'Age' column before converting to integer
df_no_duplicates['Age'] = df_no_duplicates['Age'].fillna(df_no_duplicates['Age'].mean()).astype(int)
print("\nDataframe after converting 'Age' to integer:")
print(df_no_duplicates)
# Out:
# Original Dataframe with missing values:
#       Name   Age         City
# 0    Alice  25.0     New York
# 1      Bob   NaN  Los Angeles
# 2  Charlie  30.0         None
# 3    David  35.0      Chicago
# 4    Alice   NaN     New York
#
# Missing values in each column:
# Name    0
# Age     2
# City    1
# dtype: int64
#
# Dataframe after filling missing values:
#       Name   Age         City
# 0    Alice  25.0     New York
# 1      Bob  30.0  Los Angeles
# 2  Charlie  30.0      Unknown
# 3    David  35.0      Chicago
# 4    Alice  30.0     New York
#
# Dataframe after dropping missing values:
#     Name   Age      City
# 0  Alice  25.0  New York
# 3  David  35.0   Chicago
#
# Dataframe after removing duplicates:
#       Name   Age         City
# 0    Alice  25.0     New York
# 1      Bob   NaN  Los Angeles
# 2  Charlie  30.0         None
# 3    David  35.0      Chicago
# 4    Alice   NaN     New York
#
# Dataframe after converting 'Age' to integer:
#       Name  Age         City
# ...

# %%
#decision tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.datasets import load_iris
X,y = load_iris(return_X_y=True)
model = DecisionTreeClassifier().fit(X,y)
print(model.predict(X[:5]))
# Out:
# [0 0 0 0 0]

# %%
#random forest
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import load_iris
X,y = load_iris(return_X_y=True)
model = RandomForestClassifier().fit(X,y)
print(model.score(X,y))
# Out:
# 1.0

# %%
#house price
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression # Import LinearRegression

house_size = np.array([1400,1600,1700,1875,2000]).reshape(-1, 1) # Reshape for sklearn
price = np.array([245,312,279,308,199])

# Train a Linear Regression model for house prices
model = LinearRegression()
model.fit(house_size, price)

plt.scatter(house_size,price)
plt.xlabel('house size')
plt.ylabel('price')
plt.title('House Size vs Price')
plt.show()

# Plot the regression line
plt.plot(house_size, price, 'o')
plt.plot(house_size, model.predict(house_size), color='red')
plt.xlabel('house size')
plt.ylabel('price')
plt.title('House Size vs Price with Regression Line')
plt.show()

#predict price of house
predict_price = model.predict([[1550]])
print(f"Predicted price for a 1550 sq ft house: ${predict_price[0]:.2f}")
# Out:
# Predicted price for a 1550 sq ft house: $277.05
